# %%
# %run FittingPks.ipynb
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# OSError: File `'FittingPks.ipynb;'` not found.
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 get_ipython().run_line_magic('run', 'FittingPks.ipynb;')
#
# Exception: File `'FittingPks.ipynb;'` not found.
